# %%
import numpy as np
import trueml.plots as plt

x = np.random.rand(1000)
y = np.random.rand(1000)


plt.line(x, y, marker="o", ls="--", alpha=0.4, xlabel="x", ylabel="y", color = "black", title="x vs y")
