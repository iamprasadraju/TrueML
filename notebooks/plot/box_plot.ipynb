# %%
import numpy as np
import trueml.plots as plt
x = np.random.randn(1000)

plt.box(x, title="random x", ylabel="value")

# %%
plt.box(x=[[1, 2, 3, 4, 5],[2, 3, 4, 5, 6]], labels=["Dataset A", "Dataset B"], title="Dataset Comparison", ylabel="Value",showfliers=False)
