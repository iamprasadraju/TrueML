# %%
import random
import trueml.plots as plt
x = ["A", "B", "C", "D", "F", "G"]
y = [random.randint(100, 1000) for i in range(len(x))]

plt.bar(x, y, color="pink", alpha=0.7, xlabel="x", ylabel="y", title="x vs y", figsize=(5, 4))
