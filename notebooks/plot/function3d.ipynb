# %%
# %matplotlib widget

# %%
from trueml.plots import function3d
from trueml.losses import MSEloss, MAEloss

function3d(MSEloss.surface, x_range=(-10, 10), y_range=(-10, 10), resolution=100, figsize=(6, 6), cmap="viridis", title="MSE (squared error)")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
function3d(MAEloss.surface, x_range=(-10, 10), y_range=(-10, 10), resolution=100, figsize=(6, 6), cmap="viridis", title="MAE (absolute error)")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
