# %%
from trueml.plot import function2d
from trueml.activations import linear, sigmoid

function2d(linear, x_range=(-10, 10), resolution=100, figsize=(6, 4), title="linear activation")

# %%
function2d(sigmoid, x_range=(-10, 10), resolution=100, figsize=(6, 4), title="sigmoid activation")
